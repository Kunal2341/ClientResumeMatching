# %% [markdown]
# # IMPORT

# %%
import os
from pdf2image import convert_from_path
import ntpath
from google.oauth2 import service_account
from google.cloud import vision
import io
import string
import pandas as pd
import ast
import spacy
import shutil
from shutil import copyfile
nlp = spacy.load('en_core_web_sm')

# %%
from __future__ import unicode_literals, print_function
from spacy.lang.en import English # updated

# %% [markdown]
# # PDF TO TEXT

# %%
def convert_pdf_2_image(uploaded_image_path, uploaded_image):
    project_dir = os.getcwd()
    os.chdir(uploaded_image_path)
    file_name = str(uploaded_image).replace('.pdf','')
    pages = convert_from_path(uploaded_image, 200,poppler_path='/Users/kunal/Documents/VdartWorking/Poppler/poppler-0.68.0_x86/poppler-0.68.0/bin/')
    pageNumCount = 1
    outputNames = []
    for page in pages:
        output_file = file_name+"_"+str(pageNumCount) + '.jpg'
        page.save(output_file, 'JPEG')
        pageNumCount +=1
        outputNames.append(output_file)
    return outputNames

# %%
def convert_img_2_text(imagePath):
    keyDIR = "/Users/kunal/Documents/ResumeNLPVdart/APIKEYSGOOGLE/resumeMatcher-pdf2img.json"
    credentials = service_account.Credentials.from_service_account_file(keyDIR)
    client = vision.ImageAnnotatorClient(credentials=credentials)
    with io.open(imagePath, 'rb') as image_file:
        content = image_file.read()
    image = vision.types.Image(content=content)
    response = client.text_detection(image=image)
    texts = response.text_annotations
    totalString = ''
    for text in texts:
        totalString+=text.description
    totalString = totalString.rsplit(' ', 1)[0]
    return totalString

# %%
def deleteIMG(path):
    for i in os.listdir(path):
        if i.endswith(".jpg"):
            os.remove(folder_pdf + i)
def deleteEverythingInFolder(folder_pdf):
    for file in os.listdir(folder_pdf):
        try:
            shutil.rmtree(folder_pdf+ file)
        except NotADirectoryError:
            try:
                os.remove(folder_pdf+ file)
            except:
                pass
def moveRenameAllFiles(sourceFolderResumes, folder_pdf):
    for realFile in os.listdir(sourceFolderResumes):
        copyfile(sourceFolderResumes + realFile, folder_pdf + realFile)
    os.chdir(folder_pdf)
    documentcounter = 100
    for i in os.listdir(folder_pdf):
        fileNameCreator = "Document_" + str(documentcounter) + ".pdf"
        print(i + "   changed to  " + fileNameCreator)
        os.rename(i, fileNameCreator) 
        documentcounter+=1
def checkifPNGExists(folder_pdf):
    PNGFilesExist = False
    for t in os.listdir(folder_pdf):
        if t.endswith(".png"):
            return True
    
    for t in os.listdir(folder_pdf):
        for j in os.listdir(folder_pdf+t):
            if j.endswith(".png"):
                return True
    return PNGFilesExist

# %%
numberOfFiles = len([name for name in os.listdir(folder_pdf) if os.path.isfile(name)])
# Out:
# 50

# %%
FIX THE FUNCTION WHERE IT DETECTS IF THERE IS A IMAGE THERE

# %%
#os.mkdir('/Users/kunal/Documents/ResumeNLPVdart/GoogleLabelingData')

# %%
folder_pdf = '/Users/kunal/Documents/ResumeNLPVdart/GoogleLabelingData/'
sourceFolderResumes = '/Users/kunal/Documents/ResumeNLPVdart/50_resumes/'

# %%
deleteEverythingInFolder(folder_pdf)
moveRenameAllFiles(sourceFolderResumes, folder_pdf)
PNGFilesExist = checkifPNGExists(folder_pdf)

# %%
PNGFilesExist = False

# %%
textList = []
numberPagesList = []
folder_pdf = '/Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/'
if PNGFilesExist == False:
    for i in os.listdir(folder_pdf):
        os.chdir(folder_pdf)
        folderNameCreate = folder_pdf+"Fold_"+i[:-4]+"/"
        print(folderNameCreate)
        os.mkdir(folderNameCreate)
        shutil.move(i,folderNameCreate)
        os.chdir(folderNameCreate)
        for j in os.listdir(folderNameCreate):
            print(j)
            if j.endswith(".pdf"):
                imgName = convert_pdf_2_image(folderNameCreate, j)
                print("Running Number :" + str(len(imgName))) 
                printString = ""
                for docName in imgName:
                    printString += docName + " " 
                print(printString)
            for q in range(len(imgName)):
                text = convert_img_2_text(folderNameCreate + i[:-4] + "_" + str(q+1) + ".jpg")
                textList.append(text)    
                numberPagesList.append(len(imgName))
# Out:
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_102/
# Document_102.pdf
# Running Number :6
# Document_102_1.jpg Document_102_2.jpg Document_102_3.jpg Document_102_4.jpg Document_102_5.jpg Document_102_6.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_103/
# Document_103.pdf
# Running Number :5
# Document_103_1.jpg Document_103_2.jpg Document_103_3.jpg Document_103_4.jpg Document_103_5.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_104/
# Document_104.pdf
# Running Number :3
# Document_104_1.jpg Document_104_2.jpg Document_104_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_105/
# Document_105.pdf
# Running Number :2
# Document_105_1.jpg Document_105_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_106/
# Document_106.pdf
# Running Number :2
# Document_106_1.jpg Document_106_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_107/
# Document_107.pdf
# Running Number :11
# Document_107_1.jpg Document_107_2.jpg Document_107_3.jpg Document_107_4.jpg Document_107_5.jpg Document_107_6.jpg Document_107_7.jpg Document_107_8.jpg Document_107_9.jpg Document_107_10.jpg Document_107_11.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_108/
# Document_108.pdf
# Running Number :1
# Document_108_1.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_109/
# Document_109.pdf
# Running Number :2
# Document_109_1.jpg Document_109_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_110/
# Document_110.pdf
# Running Number :2
# Document_110_1.jpg Document_110_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_111/
# Document_111.pdf
# Running Number :1
# Document_111_1.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_112/
# Document_112.pdf
# Running Number :1
# Document_112_1.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_113/
# Document_113.pdf
# Running Number :2
# Document_113_1.jpg Document_113_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_114/
# Document_114.pdf
# Running Number :3
# Document_114_1.jpg Document_114_2.jpg Document_114_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_115/
# Document_115.pdf
# Running Number :2
# Document_115_1.jpg Document_115_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_116/
# Document_116.pdf
# Running Number :2
# Document_116_1.jpg Document_116_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_117/
# Document_117.pdf
# Running Number :10
# Document_117_1.jpg Document_117_2.jpg Document_117_3.jpg Document_117_4.jpg Document_117_5.jpg Document_117_6.jpg Document_117_7.jpg Document_117_8.jpg Document_117_9.jpg Document_117_10.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_118/
# Document_118.pdf
# Running Number :3
# Document_118_1.jpg Document_118_2.jpg Document_118_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_119/
# Document_119.pdf
# Running Number :2
# Document_119_1.jpg Document_119_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_120/
# Document_120.pdf
# Running Number :2
# Document_120_1.jpg Document_120_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_121/
# Document_121.pdf
# Running Number :3
# Document_121_1.jpg Document_121_2.jpg Document_121_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_122/
# Document_122.pdf
# Running Number :2
# Document_122_1.jpg Document_122_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_123/
# Document_123.pdf
# Running Number :5
# Document_123_1.jpg Document_123_2.jpg Document_123_3.jpg Document_123_4.jpg Document_123_5.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_124/
# Document_124.pdf
# Running Number :2
# Document_124_1.jpg Document_124_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_125/
# Document_125.pdf
# Running Number :2
# Document_125_1.jpg Document_125_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_126/
# Document_126.pdf
# Running Number :2
# Document_126_1.jpg Document_126_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_127/
# Document_127.pdf
# Running Number :7
# Document_127_1.jpg Document_127_2.jpg Document_127_3.jpg Document_127_4.jpg Document_127_5.jpg Document_127_6.jpg Document_127_7.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_128/
# Document_128.pdf
# Running Number :1
# Document_128_1.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_129/
# Document_129.pdf
# Running Number :6
# Document_129_1.jpg Document_129_2.jpg Document_129_3.jpg Document_129_4.jpg Document_129_5.jpg Document_129_6.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_130/
# Document_130.pdf
# Running Number :13
# Document_130_1.jpg Document_130_2.jpg Document_130_3.jpg Document_130_4.jpg Document_130_5.jpg Document_130_6.jpg Document_130_7.jpg Document_130_8.jpg Document_130_9.jpg Document_130_10.jpg Document_130_11.jpg Document_130_12.jpg Document_130_13.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_131/
# Document_131.pdf
# Running Number :11
# Document_131_1.jpg Document_131_2.jpg Document_131_3.jpg Document_131_4.jpg Document_131_5.jpg Document_131_6.jpg Document_131_7.jpg Document_131_8.jpg Document_131_9.jpg Document_131_10.jpg Document_131_11.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_132/
# Document_132.pdf
# Running Number :3
# Document_132_1.jpg Document_132_2.jpg Document_132_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_133/
# Document_133.pdf
# Running Number :3
# Document_133_1.jpg Document_133_2.jpg Document_133_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_134/
# Document_134.pdf
# Running Number :11
# Document_134_1.jpg Document_134_2.jpg Document_134_3.jpg Document_134_4.jpg Document_134_5.jpg Document_134_6.jpg Document_134_7.jpg Document_134_8.jpg Document_134_9.jpg Document_134_10.jpg Document_134_11.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_135/
# Document_135.pdf
# Running Number :2
# Document_135_1.jpg Document_135_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_136/
# Document_136.pdf
# Running Number :9
# Document_136_1.jpg Document_136_2.jpg Document_136_3.jpg Document_136_4.jpg Document_136_5.jpg Document_136_6.jpg Document_136_7.jpg Document_136_8.jpg Document_136_9.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_137/
# Document_137.pdf
# Running Number :3
# Document_137_1.jpg Document_137_2.jpg Document_137_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_138/
# Document_138.pdf
# Running Number :3
# Document_138_1.jpg Document_138_2.jpg Document_138_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_139/
# Document_139.pdf
# Running Number :2
# Document_139_1.jpg Document_139_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_140/
# Document_140.pdf
# Running Number :2
# Document_140_1.jpg Document_140_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_141/
# Document_141.pdf
# Running Number :3
# Document_141_1.jpg Document_141_2.jpg Document_141_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_142/
# Document_142.pdf
# Running Number :2
# Document_142_1.jpg Document_142_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_143/
# Document_143.pdf
# Running Number :2
# Document_143_1.jpg Document_143_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_144/
# Document_144.pdf
# Running Number :1
# Document_144_1.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_145/
# Document_145.pdf
# Running Number :3
# Document_145_1.jpg Document_145_2.jpg Document_145_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_146/
# Document_146.pdf
# Running Number :2
# Document_146_1.jpg Document_146_2.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_147/
# Document_147.pdf
# Running Number :4
# Document_147_1.jpg Document_147_2.jpg Document_147_3.jpg Document_147_4.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_148/
# Document_148.pdf
# Running Number :5
# Document_148_1.jpg Document_148_2.jpg Document_148_3.jpg Document_148_4.jpg Document_148_5.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Document_149/
# Document_149.pdf
# Running Number :3
# Document_149_1.jpg Document_149_2.jpg Document_149_3.jpg
# /Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Fold_Document/
# Fold_Document_100
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-50ade6de357f> in <module>
#      20                 print(printString)
#      21             for q in range(len(imgName)):
# ---> 22                 text = convert_img_2_text(folderNameCreate + i[:-4] + "_" + str(q+1) + ".jpg")
#      23                 textList.append(text)
#      24                 numberPagesList.append(len(imgName))
#
# <ipython-input-12-b0dfe0212366> in convert_img_2_text(imagePath)
#       3     credentials = service_account.Credentials.from_service_account_file(keyDIR)
#       4     client = vision.ImageAnnotatorClient(credentials=credentials)
# ----> 5     with io.open(imagePath, 'rb') as image_file:
#       6         content = image_file.read()
#       7     image = vision.types.Image(content=content)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/kunal/Documents/ResumeNLPVdart/Testing_Delete/Fold_Fold_Document/Fold_Document_1.jpg'

# %%
textList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3ec86885908f> in <module>
# ----> 1 textList
#
# NameError: name 'textList' is not defined

# %% [markdown]
# ## Convert to Excel

# %%
df = pd.DataFrame() 
df['Text Extracted'] = textList
df['DocumentNum'] = numberPagesList

# %%
os.chdir('/Users/kunal/Documents/ResumeNLPVdart/ExcelFilesStorage/')

# %%
df.to_excel('test1.xlsx', index = False)

# %% [markdown]
# ## Read Excel

# %%
os.chdir('/Users/kunal/Documents/ResumeNLPVdart/ExcelFilesStorage/')

# %%
text = pd.ExcelFile("test1.xlsx")
dftext = text.parse("Sheet1")

# %%
dftext
# Out:
#                                        Text Extracted  DocumentNum
# 0   NISARGA HASSAN SREEDHAR\nSan Jose, California ...            1
# 1   Rodolfo Cornel Jr.\n13214 Fidler Ave. Downey, ...            1
# 2   Microsoft\nCERTIFIED\naws certified\nProfessio...            6
# 3   Microsoft\nCERTIFIED\naws certified\nProfessio...            6
# 4   Microsoft\nCERTIFIED\naws certified\nProfessio...            6
# ..                                                ...          ...
# 75  Software Developer, Owner\n2015\nMOES Solution...            2
# 76  Benjamin Meena\nDenver, CO 80202\nWeb Develope...            2
# 77  Managed a new and used vehicle inventory of gr...            2
# 78  JOHN HENRY TOLIVER\n1629 SWEETGUM HILL\nDECATU...            2
# 79  •Analyzed customer orders for proper revenue r...            2
#
# [80 rows x 2 columns]

# %%
text_list = dftext["Text Extracted"].tolist()
pagesList = dftext["DocumentNum"].tolist()

# %% [markdown]
# ## Check for Recommendation letters

# %%
count=0
pageNumberShortList = []
for i in text_list:
    if not count >= len(pagesList):
        pageNumberShortList.append(pagesList[count])
        count+=pagesList[count]

# %%
count=0
numb = 0
recNumList=[]
for i in text_list:
    if "Recommendation" in str(i): 
        recNumList.append(numb)
    numb+=1

# %%
recNumList
# Out:
# [72, 73]

# %%
pageNumberrunning = 1
for q in pageNumberShortList:
    for v in recNumList:
        if pageNumberrunning == v:
            print("asdfjfsdjkf")
    pageNumberrunning +=q

# %%
STILL DOESN"T WORK
# Out:
#   File "<ipython-input-61-0b3e2b57f639>", line 1
#     STILL DOESN"T WORK
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Converts the text files to an array but still split into pages

# %%
totalText = []
for u in range(len(pagesList)):
    textExtracted = ""
    for h in range(pagesList[u]):
        try:
            textExtracted = textExtracted + "\n" + text_list[u]
        except:
            continue
        totalText.append(textExtracted)

# %%
totalText = []
for u in range(len(pagesList)):
    textExtracted = ""
    if pagesList[u] == 1:
        textExtracted = text_list[u]
        #print("Added " + text_list[u][:10])
    else:
        print(u)
        for h in range(pagesList[u]):
            if (u+h == len(text_list)):
                break
            if (isinstance(text_list[u+h], str) == False):
                continue
            textExtracted = textExtracted + "\n" + text_list[u+h]
        u += h
        print(u)
    totalText.append(textExtracted)
# Out:
# 2
# 7
# 3
# 8
# 4
# 9
# 5
# 10
# 6
# 11
# 7
# 12
# 8
# 12
# 9
# 13
# 10
# 14
# 11
# 15
# 12
# 16
# 13
# 15
# 14
# 16
# 15
# 17
# 16
# 17
# 17
# 18
# 18
# 19
# 19
# 20
# 20
# 30
# 21
# 31
# 22
# 32
# 23
# 33
# 24
# 34
# 25
# 35
# 26
# 36
# 27
# 37
# 28
# 38
# 29
# 39
# 30
# 40
# 32
# 33
# 33
# 34
# 34
# 35
# 35
# 36
# 38
# 39
# 39
# 40
# 40
# 42
# 41
# 43
# 42
# 44
# 43
# 44
# 44
# 45
# 45
# 46
# 46
# 47
# 47
# 56
# 48
# 57
# 49
# 58
# 50
# 59
# 51
# 60
# 52
# 61
# 53
# 62
# 54
# 63
# 55
# 64
# 56
# 65
# 57
# 59
# 58
# 60
# 59
# 61
# 60
# 61
# 61
# 62
# 62
# 63
# 63
# 64
# 64
# 66
# 65
# 67
# 66
# 68
# 67
# 68
# 68
# 69
# 69
# 73
# 70
# 74
# 71
# 75
# 72
# 76
# 73
# 77
# 74
# 75
# 75
# 76
# 76
# 77
# 77
# 78
# 78
# 79
# 79
# 80

# %%
len(totalText)
# Out:
# 80

# %% [markdown]
# ## Var Names

# %%
print("Variable Name for text Files = ")
varNameL = []
for n, val in enumerate(textList):
    globals()["text%d"%n] = val
    varNameL.append("text%d"%n)
    #print("text%d"%n)
print("Total: " + str(n+1))
# Out:
# Variable Name for text Files =
# Total: 179

# %% [markdown]
# # Create Sentences

# %% [markdown]
# ## Create Sentences Using Full sentences -- better

# %%
# Out:
# '\nJuan Carlos Castellanos Navarro\nAurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com\nGithub: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/\nLinkedIn: www.linkedin.com/in/jccnlkdin\nSummary\nBilingual computer engineer with highly developed abstraction skills, capable to understand complex problems\nto develop solutions. Known as a team player who is able to interact effectively with clients and colleagues.\nPossessing strong leadership traits with the ability to learn how to use new tools and technologies in a short\ntime. Ready-set to achieve company goals.\nTechnical Skills\nLanguages: JavaScript, MySQL, HTML, CSS, C/C++, Java.\nLibraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize,\nMongoose, Express.js, Handlebars.js.\nDatabases: MYSQL, MongoDB.\nProjects\nTableTop Tap | Repo: https://github.com/BestBroBradley/project-two\nDemo: https://sheltered-falls-54052.herokuapp.com/\nThe admin of the website allows CRUD operations to administer what is being displayed on the site.\nThe app has two sides, Admin and Public.\nCreated Back-end functionality which includes authentication, database (design and implementation)\nand testing API routes (Postman).\nTools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js,\nsequelize, pug templating, Bulma UI.\nBurger | Repo: https://github.com/monguis/burger\nDemo:https://powerful-badlands-43542.herokuapp.com/\nThis app displays MYSQL capabilities combined with back-end API responses.\nDesign, Programming, and Deployment.\nTools/languages used: Javascript, MYSQL, express.js, Bootstrap UI.\nExperience\nSales Associate\n2016– 2019\nMicro Center\nDenver CO\nAdvised customers by listening to their problems to find the best solution for their needs with a vast inventory of\ntechnological products.\nKey Accomplishments:\nAssigned as an AMD champion.\nAs Champion, Micro Center Denver became # 1 AMD selling store in the nation for 6 months\nSoftware Developer, Owner\n2015\nMOES Solutions\nJalisco Mexico\nDesigned and developed Java applications with administrative functions, built for fast food restaurants with a\nfast-growing potential.\nKey Accomplishments:\nReduced Restaurant operation cost by 13% on average thanks to the implemented software, due to\nbetter management of ingredients and portion.\nAccomplished better sustainability for individual locations.\nEducation\nFull Stack Web Development Certificate: University of Denver, Denver CO.\nBachelors in Computer Engineering: University of Guadalajara, Guadalajara'

# %%
counter = 0
for i in totalText:
    if i.find("Juan") > 0:
        print(counter)
    counter+=1
# Out:
# 70
# 71
# 72
# 73
# 74

# %%
textChoosen = textList[10]

# %%
setnecnceAuto = []
for line in textChoosen.splitlines():
    setnecnceAuto.append(line)

# %%
sentence = ""
sentenceList = []
char = 0
addNumChar = (int(len(textChoosen)/(len(setnecnceAuto))))+1
for j in range(len(setnecnceAuto)):
    #print([str(j) + " " + textChoosen[char:char + addNumChar]])
    char += addNumChar
    addword = input("Current: >>>"+ sentence+ "<<< + >>>"+ setnecnceAuto[j] + "<<<")
    if addword == "":
        sentence += setnecnceAuto[j] + " "
    elif addword == "g":
        sentenceList.append(sentence[:-1])
        print("Added >>>"+sentence[:-1]+"<<<")
        sentence = ""
        setnecnceAuto[j: j] = ["testfff"]
    elif addword == "fff":
        break
# Out:
# Current: >>><<< + >>><<<
# Current: >>> <<< + >>>Juan Carlos Castellanos Navarro<<<
# Current: >>> Juan Carlos Castellanos Navarro <<< + >>>Aurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com<<<g
# Added >>> Juan Carlos Castellanos Navarro<<<
# Current: >>><<< + >>>Aurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com<<<
# Current: >>>Aurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com <<< + >>>Github: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/<<<g
# Added >>>Aurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com<<<
# Current: >>><<< + >>>Github: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/<<<
# Current: >>>Github: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/ <<< + >>>LinkedIn: www.linkedin.com/in/jccnlkdin<<<g
# Added >>>Github: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/<<<
# Current: >>><<< + >>>LinkedIn: www.linkedin.com/in/jccnlkdin<<<
# Current: >>>LinkedIn: www.linkedin.com/in/jccnlkdin <<< + >>>Summary<<<g
# Added >>>LinkedIn: www.linkedin.com/in/jccnlkdin<<<
# Current: >>><<< + >>>Summary<<<
# Current: >>>Summary <<< + >>>Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems<<<
# Current: >>>Summary Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems <<< + >>>to develop solutions. Known as a team player who is able to interact effectively with clients and colleagues.<<<
# Current: >>>Summary Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems to develop solutions. Known as a team player who is able to interact effectively with clients and colleagues. <<< + >>>Possessing strong leadership traits with the ability to learn how to use new tools and technologies in a short<<<
# Current: >>>Summary Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems to develop solutions. Known as a team player who is able to interact effectively with clients and colleagues. Possessing strong leadership traits with the ability to learn how to use new tools and technologies in a short <<< + >>>time. Ready-set to achieve company goals.<<<
# Current: >>>Summary Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems to develop solutions. Known as a team player who is able to interact effectively with clients and colleagues. Possessing strong leadership traits with the ability to learn how to use new tools and technologies in a short time. Ready-set to achieve company goals. <<< + >>>Technical Skills<<<g
# Added >>>Summary Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems to develop solutions. Known as a team player who is able to interact effectively with clients and colleagues. Possessing strong leadership traits with the ability to learn how to use new tools and technologies in a short time. Ready-set to achieve company goals.<<<
# Current: >>><<< + >>>Technical Skills<<<
# Current: >>>Technical Skills <<< + >>>Languages: JavaScript, MySQL, HTML, CSS, C/C++, Java.<<<g
# Added >>>Technical Skills<<<
# Current: >>><<< + >>>Languages: JavaScript, MySQL, HTML, CSS, C/C++, Java.<<<
# Current: >>>Languages: JavaScript, MySQL, HTML, CSS, C/C++, Java. <<< + >>>Libraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize,<<<g
# Added >>>Languages: JavaScript, MySQL, HTML, CSS, C/C++, Java.<<<
# Current: >>><<< + >>>Libraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize,<<<
# Current: >>>Libraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize, <<< + >>>Mongoose, Express.js, Handlebars.js.<<<
# Current: >>>Libraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize, Mongoose, Express.js, Handlebars.js. <<< + >>>Databases: MYSQL, MongoDB.<<<g
# Added >>>Libraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize, Mongoose, Express.js, Handlebars.js.<<<
# Current: >>><<< + >>>Databases: MYSQL, MongoDB.<<<
# Current: >>>Databases: MYSQL, MongoDB. <<< + >>>Projects<<<g
# Added >>>Databases: MYSQL, MongoDB.<<<
# Current: >>><<< + >>>Projects<<<
# Current: >>>Projects <<< + >>>TableTop Tap | Repo: https://github.com/BestBroBradley/project-two<<<
# Current: >>>Projects TableTop Tap | Repo: https://github.com/BestBroBradley/project-two <<< + >>>Demo: https://sheltered-falls-54052.herokuapp.com/<<<g
# Added >>>Projects TableTop Tap | Repo: https://github.com/BestBroBradley/project-two<<<
# Current: >>><<< + >>>Demo: https://sheltered-falls-54052.herokuapp.com/<<<
# Current: >>>Demo: https://sheltered-falls-54052.herokuapp.com/ <<< + >>>The admin of the website allows CRUD operations to administer what is being displayed on the site.<<<g
# Added >>>Demo: https://sheltered-falls-54052.herokuapp.com/<<<
# Current: >>><<< + >>>The admin of the website allows CRUD operations to administer what is being displayed on the site.<<<
# Current: >>>The admin of the website allows CRUD operations to administer what is being displayed on the site. <<< + >>>The app has two sides, Admin and Public.<<<
# Current: >>>The admin of the website allows CRUD operations to administer what is being displayed on the site. The app has two sides, Admin and Public. <<< + >>>Created Back-end functionality which includes authentication, database (design and implementation)<<<g
# Added >>>The admin of the website allows CRUD operations to administer what is being displayed on the site. The app has two sides, Admin and Public.<<<
# Current: >>><<< + >>>Created Back-end functionality which includes authentication, database (design and implementation)<<<
# Current: >>>Created Back-end functionality which includes authentication, database (design and implementation) <<< + >>>and testing API routes (Postman).<<<
# Current: >>>Created Back-end functionality which includes authentication, database (design and implementation) and testing API routes (Postman). <<< + >>>Tools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js,<<<g
# Added >>>Created Back-end functionality which includes authentication, database (design and implementation) and testing API routes (Postman).<<<
# Current: >>><<< + >>>Tools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js,<<<
# Current: >>>Tools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js, <<< + >>>sequelize, pug templating, Bulma UI.<<<
# Current: >>>Tools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js, sequelize, pug templating, Bulma UI. <<< + >>>Burger | Repo: https://github.com/monguis/burger<<<g
# Added >>>Tools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js, sequelize, pug templating, Bulma UI.<<<
# Current: >>><<< + >>>Burger | Repo: https://github.com/monguis/burger<<<
# Current: >>>Burger | Repo: https://github.com/monguis/burger <<< + >>>Demo:https://powerful-badlands-43542.herokuapp.com/<<<
# Current: >>>Burger | Repo: https://github.com/monguis/burger Demo:https://powerful-badlands-43542.herokuapp.com/ <<< + >>>This app displays MYSQL capabilities combined with back-end API responses.<<<g
# Added >>>Burger | Repo: https://github.com/monguis/burger Demo:https://powerful-badlands-43542.herokuapp.com/<<<
# Current: >>><<< + >>>This app displays MYSQL capabilities combined with back-end API responses.<<<
# Current: >>>This app displays MYSQL capabilities combined with back-end API responses. <<< + >>>Design, Programming, and Deployment.<<<g
# Added >>>This app displays MYSQL capabilities combined with back-end API responses.<<<
# Current: >>><<< + >>>Design, Programming, and Deployment.<<<
# Current: >>>Design, Programming, and Deployment. <<< + >>>Tools/languages used: Javascript, MYSQL, express.js, Bootstrap UI.<<<g
# Added >>>Design, Programming, and Deployment.<<<
# Current: >>><<< + >>>Tools/languages used: Javascript, MYSQL, express.js, Bootstrap UI.<<<
# Current: >>>Tools/languages used: Javascript, MYSQL, express.js, Bootstrap UI. <<< + >>>Experience<<<g
# Added >>>Tools/languages used: Javascript, MYSQL, express.js, Bootstrap UI.<<<
# Current: >>><<< + >>>Experience<<<
# Current: >>>Experience <<< + >>>Sales Associate<<<g
# Added >>>Experience<<<
# Current: >>><<< + >>>Sales Associate<<<
# Current: >>>Sales Associate <<< + >>>2016– 2019<<<
# Current: >>>Sales Associate 2016– 2019 <<< + >>>Micro Center<<<g
# Added >>>Sales Associate 2016– 2019<<<

# %%
sentenceList
# Out:
# [' Juan Carlos Castellanos Navarro',
#  'Aurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com',
#  'Github: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/',
#  'LinkedIn: www.linkedin.com/in/jccnlkdin',
#  'Summary Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems to develop solutions. Known as a team player who is able to interact effectively with clients and colleagues. Possessing strong leadership traits with the ability to learn how to use new tools and technologies in a short time. Ready-set to achieve company goals.',
#  'Technical Skills',
#  'Languages: JavaScript, MySQL, HTML, CSS, C/C++, Java.',
#  'Libraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize, Mongoose, Express.js, Handlebars.js.',
#  'Databases: MYSQL, MongoDB.',
#  'Projects TableTop Tap | Repo: https://github.com/BestBroBradley/project-two',
#  'Demo: https://sheltered-falls-54052.herokuapp.com/',
#  'The admin of the website allows CRUD operations to administer what is being displayed on the site. The app has two sides, Admin and Public.',
#  'Created Back-end functionality which includes authentication, database (design and implementation) and testing API routes (Postman).',
#  'Tools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js, sequelize, pug templating, Bulma UI.',
#  'Burger | Repo: https://github.com/monguis/burger Demo:https://powerful-badlands-43542.herokuapp.com/',
#  'This app displays MYSQL capabilities combined with back-end API responses.',
#  'Design, Programming, and Deployment.',
#  'Tools/languages used: Javascript, MYSQL, express.js, Bootstrap UI.',
#  'Experience',
#  'Sales Associate 2016– 2019']

# %%
sentenceList = [' Juan Carlos Castellanos Navarro',
 'Aurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com',
 'Github: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/',
 'LinkedIn: www.linkedin.com/in/jccnlkdin',
 'Summary Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems to develop solutions. Known as a team player who is able to interact effectively with clients and colleagues. Possessing strong leadership traits with the ability to learn how to use new tools and technologies in a short time. Ready-set to achieve company goals.',
 'Technical Skills',
 'Languages: JavaScript, MySQL, HTML, CSS, C/C++, Java.',
 'Libraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize, Mongoose, Express.js, Handlebars.js.',
 'Databases: MYSQL, MongoDB.',
 'Projects TableTop Tap | Repo: https://github.com/BestBroBradley/project-two',
 'Demo: https://sheltered-falls-54052.herokuapp.com/',
 'The admin of the website allows CRUD operations to administer what is being displayed on the site. The app has two sides, Admin and Public.',
 'Created Back-end functionality which includes authentication, database (design and implementation) and testing API routes (Postman).',
 'Tools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js, sequelize, pug templating, Bulma UI.',
 'Burger | Repo: https://github.com/monguis/burger Demo:https://powerful-badlands-43542.herokuapp.com/',
 'This app displays MYSQL capabilities combined with back-end API responses.',
 'Design, Programming, and Deployment.',
 'Tools/languages used: Javascript, MYSQL, express.js, Bootstrap UI.',
 'Experience',
 'Sales Associate 2016– 2019',
 'Micro Center',
 'Denver CO',
 'Advised customers by listening to their problems to find the best solution for their needs with a vast inventory of technological products.',
 'Key Accomplishments:',
 'Assigned as an AMD champion.',
 'As Champion, Micro Center Denver became # 1 AMD selling store in the nation for 6 months',
 'Software Developer, Owner',
 '2015',
 'MOES Solutions Jalisco Mexico',
 'Designed and developed Java applications with administrative functions, built for fast food restaurants with a ast-growing potential.',
 'Key Accomplishments:',
 'Reduced Restaurant operation cost by 13% on average thanks to the implemented software, due to better management of ingredients and portion.',
 'Accomplished better sustainability for individual locations.',
 'Education',
 'Full Stack Web Development Certificate: University of Denver, Denver CO.',
 'Bachelors in Computer Engineering: University of Guadalajara, Guadalajara']

# %% [markdown]
# ## Create Sentences Using Words splitter

# %%
word = ""
listofWords = []
for i in textList[5]:
    if not (i == " " or i == "\n"):
        word += i 
    else:
        listofWords.append(word)
        word = ""

# %%
sentence = ""
sentenceList = []
for j in range(len(listofWords)):
    #print(listofWords[j])
    #print("running " + listofWords[j])
    addword = input("Current: >>>"+ sentence+ "<<< + >>>"+ listofWords[j] + "<<<")
    if addword == "":
        sentence += listofWords[j] + " "
    elif addword == "g":
        sentenceList.append(sentence[:-1])
        print("Added >>>"+sentence[:-1]+"<<<")
        sentence = ""
        listofWords[j: j] = ["testfff"]
    elif addword == "fff":
        break

# %% [markdown]
# ## FINAL SENTENCE LIST MADE

# %% [raw]
# sentenceList = ['Microsoft CERTIFIED',
#  'aws certified',
#  'Professional',
#  'Hem Chandra',
#  'Rockville, Maryland',
#  '469-436-9015',
#  'manoj@centillioninfotech.com',
#  'OBJECTIVE: Lead Developer with more than 15+ years of experience in full-stack development (C#, VB.NET, .Net, ASP.NET, ASP.NET MVC, Web API, Angular, AWS, SharePoint, InfoPath, SQL Server, SSIS, SSRS, Web services, WCF, LINQ, XML, TFS 2010/13, SVN, VSS, GitHub, Telerik Controls, UML, JQuery and JavaScript) for building various desktop and web applications.',
#  'SUMMARY:',
#  'Working experience on ASP.NET, ASP.NET MVC framework, Web API and Entity Framework.',
#  'Working experience on SharePoint 2013 and SharePoint 2010.',
#  'Proficiently learned AWS (Design, Deployment, AWS EC2, S3, Cloud watch, Load balancing & Lambda etc.).',
#  'Understanding of Microsoft Azure Cloud (Design, Deployment, app services, Azure Functions etc.).',
#  'Extensive experience in coding using C# and VB.NET experience of various designs patterns (GOF).',
#  'in Creation, Development and Deployment of SSIS packages in SQL Server.',
#  'Used SQL Profiler for Performance monitor to resolve Dead Locks and long running queries by checking appropriate changes to Transaction Isolation levels',
#  'Database Performance of Index tuning with using Database Engine Tuning Advisor to resolve Performance issues.',
#  'Performed and fine-tuned Stored Procedures, SQL Queries and User Defined Functions.',
#  'Extensive experience in developing UML Models using Visio and Rational Rose.',
#  'Practical experience to implement SOA (Service Oriented Architecture: WCF) and Three-tier architecture.',
#  'Methodology: AGILE, Scrum, Test Driven Development.',
#  'Worked as TFS administrator (TFS Server setup, installation, collection creation, build automation, branching & merging etc.)',
#  'Vertical/Domain Experience: Travel, Banking, Insurance, Chemical, Water and Energy',
#  'Proficiently learned new technology Angular to meet client need.',
#  'PROFESSIONAL EXPERIENCE Maryland Department of Labor',
#  'Lead Developer',
#  'Description:',
#  'Foreclosure System-The Foreclosure Registration System is a web-based application for submission of those foreclosure-related notices and registrations that are mandated by Maryland law. System verifies lender companies using Nationwide Multistate Licensing System & Registry',
#  '(NMLS). Application is divided into three sub-systems. 1.',
#  'NOI (Notice of Intent to Foreclose): Lender companies can submit NOI to DLLR. Notice is created in pdf and send to borrower thorough email as well as by post. User can also upload predefined csv files for bulk submission.',
#  'SSIS package reads and saves data into database. System sends processed NOI status email to user.',
#  '2. NOF (Notice of Foreclosure Filing): Lender submits NOF in the system which creates notice in pdf and sends NOF to borrower through email.']

# %%
os.chdir('/Users/kunal/Documents/ResumeNLPVdart/ExcelFilesStorage/')

# %%
df = pd.DataFrame(sentenceList)
df.to_excel("sentenceLIST7th.xlsx")

# %% [markdown]
# # Convert Array to JSON

# %% [markdown]
# ## Extract Excel and Turn into a list

# %%
os.chdir('/Users/kunal/Documents/ResumeNLPVdart/ExcelFilesStorage/')

# %%
text = pd.ExcelFile("sentenceLISTT.xlsx")
totalTextRunning = totalText[0]
attributes = text.parse("Sheet1")

# %%
attributes
# Out:
#                                                  Text      Unnamed: 1  \
# 0                             NISARGA HASSAN SREEDHAR            Name
# 1                                San Jose, California        Location
# 2                                 |+1 (925) 789-8911|           Phone
# 3                           nisarga.nishu20@gmail.com           email
# 4                                                   |            none
# ..                                                ...             ...
# 58  Tested and troubleshot configurations in the c...            none
# 59          Design of X-Band 8PSK Modulator using ADS        Hardware
# 60                              Jan 2017 - April 2017            Date
# 61  Designed various components of the modulator u...         Company
# 62  Performed optimization of the components at 8....  MultipleSkills
#
#                                          Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                               All        NaN        NaN
# 1                                               All        NaN        NaN
# 2                                    (925) 789-8911        NaN        NaN
# 3                                               All        NaN        NaN
# 4                                               NaN        NaN        NaN
# ..                                              ...        ...        ...
# 58                                              NaN        NaN        NaN
# 59                            X-Band 8PSK Modulator        NaN        NaN
# 60                                              All        NaN        NaN
# 61        ISRO (Indian Space Research Organization)        NaN        NaN
# 62  Insertion loss, Return loss and Isolation loss.        NaN        NaN
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0         NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN        NaN        NaN        NaN        NaN         NaN
# 3         NaN        NaN        NaN        NaN        NaN         NaN
# 4         NaN        NaN        NaN        NaN        NaN         NaN
# ..        ...        ...        ...        ...        ...         ...
# 58        NaN        NaN        NaN        NaN        NaN         NaN
# 59        NaN        NaN        NaN        NaN        NaN         NaN
# 60        NaN        NaN        NaN        NaN        NaN         NaN
# 61        NaN        NaN        NaN        NaN        NaN         NaN
# 62        NaN        NaN        NaN        NaN        NaN         NaN
#
# [63 rows x 11 columns]

# %%
RowList = attributes.values.tolist()

# %%
attributeList = [[i for i in row if isinstance(i,str)] for row in RowList]

# %% [markdown]
# ## Create Final List

# %%
def sentence_2_word(sentence):
    word = ""
    listofWords = []
    for i in sentence:
        if not (i == " " or i == "\n"):
            word += i 
        else:
            listofWords.append(word)
            word = ""
    if len(listofWords) == 0:
        listofWords.append(sentence)
    return listofWords

# %%
def find_all_indexes(input_str, search_str):
    l1 = []
    length = len(input_str)
    index = 0
    while index < length:
        i = input_str.find(search_str, index)
        if i == -1:
            return l1
        l1.append(i)
        index = i + 1
    return l1[0]

# %%
attributesNumberList = []
for j in attributeList:
    runningAttributeNum = []
    if len(j) == 2:
        continue
    if j[2] == "All":
        startChar = totalTextRunning.find(j[0])
        endChar = startChar + len(j[0])
        runningAttributeNum.extend([j[1].upper() , startChar, endChar])
        attributesNumberList.append(runningAttributeNum)
    else:
        #print("RUNNING " + str(int((len(j)-1)/2)))
        for w in range(0, int((len(j)-1)), 2):
            runningAttributeNum = []
            if not totalTextRunning.find(j[2+w]) == -1:
                startChar = totalTextRunning.find(j[2+w])
                endChar = startChar + len(j[2+w])
                runningAttributeNum.extend([j[1+w].upper(), startChar, endChar])
            else:
                words = sentence_2_word(j[2+w])
                detected = 0
                for g in words:
                    if not j[2+w].find(g) == -1:
                        #charTemp = j[2+w].find(g)
                        detected+=1
                if detected/len(words) > 0.95:
                    startChar = totalTextRunning.find(words[0])
                    endChar = startChar + len(words[0])
                    runningAttributeNum.extend([words[0].upper(), startChar, endChar])
                else:
                    charTemp = -1
                    print("NOT DETECTED")
                    endChar , startChar = -1
                    runningAttributeNum.extend(["NOTDETECTED", startChar, endChar])
            attributesNumberList.append(runningAttributeNum)

# %%
attributesNumberList
# Out:
# [['NAME', 0, 23],
#  ['LOCATION', 24, 44],
#  ['PHONE', 49, 63],
#  ['EMAIL', 65, 90],
#  ['LINKEDIN', 93, 139],
#  ['EDUCATION', 151, 207],
#  ['LOCATION', 208, 252],
#  ['SKILL', 187, 206],
#  ['EDUCATION', 366, 422],
#  ['SKILL', 282, 306],
#  ['DAYANANDA', 424, 433],
#  ['DATE', 509, 517],
#  ['DATE', 518, 527],
#  ['HTTP,', 568, 573],
#  ['SOFTWARE', 754, 760],
#  ['SOFTWARE', 774, 779],
#  ['SOFTWARE', 781, 787],
#  ['CENTOS', -1, 5],
#  ['SOFTWARE', 798, 808],
#  ['SOFTWARE', 810, 819],
#  ['SOFTWARE', 865, 874],
#  ['SOFTWARE', 876, 894],
#  ['SOFTWARE', 896, 906],
#  ['SOFTWARE', 914, 933],
#  ['AWARDCERTIFICATION', 956, 996],
#  ['COMPANY ', 810, 815],
#  ['AWARDCERTIFICATION', 1005, 1047],
#  ['DATE', 1088, 1109],
#  ['COMPANY', 1110, 1146],
#  ['LOCATION', 1148, 1164],
#  ['SKILL', 1165, 1188],
#  ['SOFTWARE', 754, 760],
#  ['SKILL', 1202, 1222],
#  ['SOFTWARE', 754, 760],
#  ['DATE', 1464, 1472],
#  ['HARDWARE', 914, 933],
#  ['COMPANY ', 810, 815],
#  ['SOFTWARE', 798, 808],
#  ['HARDWARE', 1696, 1711],
#  ['DATE', 1712, 1731],
#  ['HARDWARE', 1696, 1711],
#  ['HARDWARE', 1778, 1793],
#  ['SOFTWARE', 1798, 1818],
#  ['SOFTWARE', 1900, 1923],
#  ['COMPANY', 2000, 2032],
#  ['DATE', 1464, 1472],
#  ['DATE', 1723, 1731],
#  ['COMPANY', 2026, 2031],
#  ['SOFTWARE', 2140, 2155],
#  ['SOFTWARE', 2282, 2307],
#  ['DATE', 2355, 2363],
#  ['DATE', 2366, 2376],
#  ['SOFTWARE', 781, 787],
#  ['DATE', 1464, 1467],
#  ['DATE', 2675, 2679],
#  ['DATE', 2682, 2690],
#  ['MULTIPLESKILLS', 2885, 2929],
#  ['HARDWARE', 3042, 3064],
#  ['DATE', 3075, 3096],
#  ['COMPANY', 3165, 3206],
#  ['INSERTION', 3347, 3356]]

# %%
for testing in attributesNumberList:
    if testing[1] == -1:
        attributesNumberList.remove(testing)

# %% [markdown]
# ## DataSet to JSON FILE

# %%
len(attributesNumberList)
# Out:
# 60

# %%
attributeCount = len(attributesNumberList)
text = totalText[74]
#text = totalText[0] + totalText[35] + totalText[74] 
attributes = attributesNumberList

# %%
text
# Out:
# '\nJuan Carlos Castellanos Navarro\nAurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com\nGithub: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/\nLinkedIn: www.linkedin.com/in/jccnlkdin\nSummary\nBilingual computer engineer with highly developed abstraction skills, capable to understand complex problems\nto develop solutions. Known as a team player who is able to interact effectively with clients and colleagues.\nPossessing strong leadership traits with the ability to learn how to use new tools and technologies in a short\ntime. Ready-set to achieve company goals.\nTechnical Skills\nLanguages: JavaScript, MySQL, HTML, CSS, C/C++, Java.\nLibraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize,\nMongoose, Express.js, Handlebars.js.\nDatabases: MYSQL, MongoDB.\nProjects\nTableTop Tap | Repo: https://github.com/BestBroBradley/project-two\nDemo: https://sheltered-falls-54052.herokuapp.com/\nThe admin of the website allows CRUD operations to administer what is being displayed on the site.\nThe app has two sides, Admin and Public.\nCreated Back-end functionality which includes authentication, database (design and implementation)\nand testing API routes (Postman).\nTools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js,\nsequelize, pug templating, Bulma UI.\nBurger | Repo: https://github.com/monguis/burger\nDemo:https://powerful-badlands-43542.herokuapp.com/\nThis app displays MYSQL capabilities combined with back-end API responses.\nDesign, Programming, and Deployment.\nTools/languages used: Javascript, MYSQL, express.js, Bootstrap UI.\nExperience\nSales Associate\n2016– 2019\nMicro Center\nDenver CO\nAdvised customers by listening to their problems to find the best solution for their needs with a vast inventory of\ntechnological products.\nKey Accomplishments:\nAssigned as an AMD champion.\nAs Champion, Micro Center Denver became # 1 AMD selling store in the nation for 6 months\nSoftware Developer, Owner\n2015\nMOES Solutions\nJalisco Mexico\nDesigned and developed Java applications with administrative functions, built for fast food restaurants with a\nfast-growing potential.\nKey Accomplishments:\nReduced Restaurant operation cost by 13% on average thanks to the implemented software, due to\nbetter management of ingredients and portion.\nAccomplished better sustainability for individual locations.\nEducation\nFull Stack Web Development Certificate: University of Denver, Denver CO.\nBachelors in Computer Engineering: University of Guadalajara, Guadalajara'

# %%
def createJSONFILE(attributeCount, text, attributes):
    alphab = list(string.ascii_lowercase)
    for alpa in range(int(attributeCount/26)):
        alphab.extend(list(string.ascii_lowercase))
    totalString = """{
        "annotations": [
            attributeCODE
        ],
        "text_snippet": {
            "content": "textCODE"
        }
    }

    """
    attributeString = """       
        {
          "text_extraction": {
            "text_segment": {
              "end_offset": eCharCODE,
              "start_offset": sCharCODE
            }
          },
          "display_name": "AtribnameCODE"
        },
    """
    totalString =  totalString.replace("textCODE", text)
    tempStringReplacer = ""
    for i in range(attributeCount):
        tempStringReplacer+=("atriCODE"+str(i+1)+alphab[i]+"\n")
    totalString = totalString.replace("attributeCODE", tempStringReplacer)
    for i in range(attributeCount):
        attributeStringNEW = attributeString
        #print(attributes[i])
        attributeStringNEW = attributeStringNEW.replace("AtribnameCODE", attributes[i][0])
        attributeStringNEW = attributeStringNEW.replace("sCharCODE", str(attributes[i][1])).replace("eCharCODE", str(attributes[i][2]))
        totalString = totalString.replace(("atriCODE"+str(i+1)+alphab[i]), attributeStringNEW)
    return totalString

# %% [markdown]
# ## Final Run Create JSON

# %%
file = createJSONFILE(attributeCount, text, attributes)

# %%
attributeCount
# Out:
# 60

# %%
print(file)
# Out:
# {
#         "annotations": [
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 23,
#               "start_offset": 0
#             }
#           },
#           "display_name": "NAME"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 44,
#               "start_offset": 24
#             }
#           },
#           "display_name": "LOCATION"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 63,
#               "start_offset": 49
#             }
#           },
#           "display_name": "PHONE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 90,
#               "start_offset": 65
#             }
#           },
#           "display_name": "EMAIL"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 139,
#               "start_offset": 93
#             }
#           },
#           "display_name": "LINKEDIN"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 207,
#               "start_offset": 151
#             }
#           },
#           "display_name": "EDUCATION"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 252,
#               "start_offset": 208
#             }
#           },
#           "display_name": "LOCATION"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 206,
#               "start_offset": 187
#             }
#           },
#           "display_name": "SKILL"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 422,
#               "start_offset": 366
#             }
#           },
#           "display_name": "EDUCATION"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 306,
#               "start_offset": 282
#             }
#           },
#           "display_name": "SKILL"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 433,
#               "start_offset": 424
#             }
#           },
#           "display_name": "DAYANANDA"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 517,
#               "start_offset": 509
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 527,
#               "start_offset": 518
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 573,
#               "start_offset": 568
#             }
#           },
#           "display_name": "HTTP,"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 760,
#               "start_offset": 754
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 779,
#               "start_offset": 774
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 787,
#               "start_offset": 781
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 808,
#               "start_offset": 798
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 819,
#               "start_offset": 810
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 874,
#               "start_offset": 865
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 894,
#               "start_offset": 876
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 906,
#               "start_offset": 896
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 933,
#               "start_offset": 914
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 996,
#               "start_offset": 956
#             }
#           },
#           "display_name": "AWARDCERTIFICATION"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 815,
#               "start_offset": 810
#             }
#           },
#           "display_name": "COMPANY "
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1047,
#               "start_offset": 1005
#             }
#           },
#           "display_name": "AWARDCERTIFICATION"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1109,
#               "start_offset": 1088
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1146,
#               "start_offset": 1110
#             }
#           },
#           "display_name": "COMPANY"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1164,
#               "start_offset": 1148
#             }
#           },
#           "display_name": "LOCATION"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1188,
#               "start_offset": 1165
#             }
#           },
#           "display_name": "SKILL"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 760,
#               "start_offset": 754
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1222,
#               "start_offset": 1202
#             }
#           },
#           "display_name": "SKILL"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 760,
#               "start_offset": 754
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1472,
#               "start_offset": 1464
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 933,
#               "start_offset": 914
#             }
#           },
#           "display_name": "HARDWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 815,
#               "start_offset": 810
#             }
#           },
#           "display_name": "COMPANY "
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 808,
#               "start_offset": 798
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1711,
#               "start_offset": 1696
#             }
#           },
#           "display_name": "HARDWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1731,
#               "start_offset": 1712
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1711,
#               "start_offset": 1696
#             }
#           },
#           "display_name": "HARDWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1793,
#               "start_offset": 1778
#             }
#           },
#           "display_name": "HARDWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1818,
#               "start_offset": 1798
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1923,
#               "start_offset": 1900
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2032,
#               "start_offset": 2000
#             }
#           },
#           "display_name": "COMPANY"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1472,
#               "start_offset": 1464
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1731,
#               "start_offset": 1723
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2031,
#               "start_offset": 2026
#             }
#           },
#           "display_name": "COMPANY"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2155,
#               "start_offset": 2140
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2307,
#               "start_offset": 2282
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2363,
#               "start_offset": 2355
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2376,
#               "start_offset": 2366
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 787,
#               "start_offset": 781
#             }
#           },
#           "display_name": "SOFTWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 1467,
#               "start_offset": 1464
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2679,
#               "start_offset": 2675
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2690,
#               "start_offset": 2682
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 2929,
#               "start_offset": 2885
#             }
#           },
#           "display_name": "MULTIPLESKILLS"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 3064,
#               "start_offset": 3042
#             }
#           },
#           "display_name": "HARDWARE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 3096,
#               "start_offset": 3075
#             }
#           },
#           "display_name": "DATE"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 3206,
#               "start_offset": 3165
#             }
#           },
#           "display_name": "COMPANY"
#         },
#
#
#         {
#           "text_extraction": {
#             "text_segment": {
#               "end_offset": 3356,
#               "start_offset": 3347
#             }
#           },
#           "display_name": "INSERTION"
#         },
#
#
#         ],
#         "text_snippet": {
#             "content": "
# Juan Carlos Castellanos Navarro
# Aurora CO 80247 | Phone: 7209710087 | Email: jccnnetwork@gmail.com
# Github: http://github.com/monguis/ | Portfolio: https://jccn-portfolio.herokuapp.com/
# LinkedIn: www.linkedin.com/in/jccnlkdin
# Summary
# Bilingual computer engineer with highly developed abstraction skills, capable to understand complex problems
# to develop solutions. Known as a team player who is able to interact effectively with clients and colleagues.
# Possessing strong leadership traits with the ability to learn how to use new tools and technologies in a short
# time. Ready-set to achieve company goals.
# Technical Skills
# Languages: JavaScript, MySQL, HTML, CSS, C/C++, Java.
# Libraries: React, Amazon S3, jQuery, Bootstrap UI, Materialize UI, Pug templating, Node.js, Sequelize,
# Mongoose, Express.js, Handlebars.js.
# Databases: MYSQL, MongoDB.
# Projects
# TableTop Tap | Repo: https://github.com/BestBroBradley/project-two
# Demo: https://sheltered-falls-54052.herokuapp.com/
# The admin of the website allows CRUD operations to administer what is being displayed on the site.
# The app has two sides, Admin and Public.
# Created Back-end functionality which includes authentication, database (design and implementation)
# and testing API routes (Postman).
# Tools / languages used: Javascript, MYSQL,HTML, CSS, Passport.js(local-strategy), express.js,
# sequelize, pug templating, Bulma UI.
# Burger | Repo: https://github.com/monguis/burger
# Demo:https://powerful-badlands-43542.herokuapp.com/
# This app displays MYSQL capabilities combined with back-end API responses.
# Design, Programming, and Deployment.
# Tools/languages used: Javascript, MYSQL, express.js, Bootstrap UI.
# Experience
# Sales Associate
# 2016– 2019
# Micro Center
# Denver CO
# Advised customers by listening to their problems to find the best solution for their needs with a vast inventory of
# technological products.
# Key Accomplishments:
# Assigned as an AMD champion.
# As Champion, Micro Center Denver became # 1 AMD selling store in the nation for 6 months
# Software Developer, Owner
# 2015
# MOES Solutions
# Jalisco Mexico
# Designed and developed Java applications with administrative functions, built for fast food restaurants with a
# fast-growing potential.
# Key Accomplishments:
# Reduced Restaurant operation cost by 13% on average thanks to the implemented software, due to
# better management of ingredients and portion.
# Accomplished better sustainability for individual locations.
# Education
# Full Stack Web Development Certificate: University of Denver, Denver CO.
# Bachelors in Computer Engineering: University of Guadalajara, Guadalajara"
#         }
#     }

# %%
jsonFormatUpload = ast.literal_eval(file)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\kunal\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-110-266ef58608d1>", line 1, in <module>
#     jsonFormatUpload = ast.literal_eval(file)
#
#   File "C:\Users\kunal\Anaconda3\lib\ast.py", line 46, in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#
#   File "C:\Users\kunal\Anaconda3\lib\ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 435
#     "content": "
#                 ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ## Test DataSet

# %%
dataset = """{
  "annotations": [
    {
      "text_extraction": {
        "text_segment": {
          "end_offset": 67,
          "start_offset": 62
        }
      },
      "display_name": "Modifier"
    },
    {
      "text_extraction": {
        "text_segment": {
          "end_offset": 158,
          "start_offset": 141
        }
      },
      "display_name": "SpecificDisease"
    }
  ],
  "text_snippet": {
    "content": "10051005\tA common MSH2 mutation in English and North American HNPCC families:
      origin, phenotypic expression, and sex specific differences in colorectal cancer .\tThe
      frequency , origin , and phenotypic expression of a germline MSH2 gene mutation previously
      identified in seven kindreds with hereditary non-polyposis cancer syndrome (HNPCC) was
      investigated . The mutation ( A-- > T at nt943 + 3 ) disrupts the 3 splice site of exon 5
      leading to the deletion of this exon from MSH2 mRNA and represents the only frequent MSH2
      mutation so far reported . Although this mutation was initially detected in four of 33
      colorectal cancer families analysed from eastern England , more extensive analysis has
      reduced the frequency to fou"
  }
}"""

# %% [markdown]
# # Upload to Google Bucket

# %%
from gcloud import storage
from oauth2client.service_account import ServiceAccountCredentials
import os


credentials_dict = {
    'type': 'service_account',
    'client_id': os.environ['BACKUP_CLIENT_ID'],
    'client_email': os.environ['BACKUP_CLIENT_EMAIL'],
    'private_key_id': os.environ['BACKUP_PRIVATE_KEY_ID'],
    'private_key': os.environ['BACKUP_PRIVATE_KEY'],
}
credentials = ServiceAccountCredentials.from_json_keyfile_dict(
    credentials_dict
)
client = storage.Client(credentials=credentials, project='myproject')
bucket = client.get_bucket('mybucket')
blob = bucket.blob('myfile')
blob.upload_from_filename('myfile')

# %%
from google.cloud import storage

def upload_to_bucket(blob_name, path_to_file, bucket_name):
    """ Upload data to a bucket"""

    # Explicitly use service account credentials by specifying the private key
    # file.
    storage_client = storage.Client.from_service_account_json(
        'creds.json') ALREADY CRAETED KEY

    #print(buckets = list(storage_client.list_buckets())

    bucket = storage_client.get_bucket(bucket_name)
    blob = bucket.blob(blob_name)
    blob.upload_from_filename(path_to_file)

    #returns a public url
    return blob.public_url

# %% [markdown]
# # Check Attributes for each Sentence in Document

# %%
for i in sentenceList:
    print(checkattributes(i))

# %%
## SPACY

# %%
def checkattributes(text):
    doc = nlp(text)
    EMAILLIST = extract_emails(doc)
    NAMELIST = extract_person_names(doc)
    #print(NAMELIST)
    #print(EMAILLIST)
    if (NAMELIST == [] and not EMAILLIST == []) or (not EMAILLIST == [] and not NAMELIST == []):
        return ["EMAIL", EMAILLIST[0][0], EMAILLIST[0][1], EMAILLIST[0][2]]
    #elif EMAILLIST == [] and not NAMELIST == []:
        #return ["NAME", NAMELIST[0][0], NAMELIST[0][1], NAMELIST[0][2]]
    #elif NAMELIST == [] and EMAILLIST == []:
        #return ["N/A", "" , 0,  0]
    else:
        return ["N/A", "" , 0,  0]
def extract_emails(doc):
    resultlis = []
    for token in doc:
        if token.like_email:
            resultlis.append((token.text,token.idx, token.idx + len(token)))
    return resultlis
def extract_person_names(doc):
    personL = []
    for entity in doc.ents:
        if entity.label_=="PERSON":
            personL.append([entity.text, entity.start_char, entity.end_char])
    return personL

# %% [markdown]
# # Create JSON from Array -- NOTWORKING

# %%
attributeCount = 3
sentenceCount = 2
text = "NISARGA HASSAN SREEDHAR"
attributes = [["NAME", "NISARGA HASSAN SREEDHAR", 0, 23],
              ["LOCATION", "San Jose, California", 12, 18],
              ["PROGRAMMING LANGUAGE", "PYTHON", 17, 20]]

# %%
def createJSON(attributeCount, sentenceCount, text, attributes):
    totalString = """
    "sentenceCode": [
        "text": "textCODE",
        "entities" : [
    attributeCODE
        ]
    ],
    """
    attributeString = """       "attributeCode" : {
               "Atribname": "AtribnameCODE",
               "textDetected": "textDetectedCODE",
               "sChar": sCharCODE,
               "eChar": eCharCODE
           }
    """
    sentenceStringReplacer = "sentence" + str(sentenceCount)
    totalString =  totalString.replace("sentenceCode", sentenceStringReplacer)
    totalString =  totalString.replace("textCODE", text)
    tempStringReplacer = ""
    for i in range(attributeCount):
        tempStringReplacer+=("atriCODE"+str(i+1)+"\n")
    totalString = totalString.replace("attributeCODE", tempStringReplacer)
    for i in range(attributeCount):
        attributeStringNEW = attributeString
        print(attributes[i])
        attributeStringNEW = attributeStringNEW.replace("AtribnameCODE", attributes[i][0]).replace("textDetectedCODE", attributes[i][1])
        attributeStringNEW = attributeStringNEW.replace("sCharCODE", str(attributes[i][2])).replace("eCharCODE", str(attributes[i][3]))
        totalString = totalString.replace(("atriCODE"+str(i+1)), attributeStringNEW)
    return totalString

# %%
data = """
{
    "Document1Sentences" : [
        "sentence1": [
            "text": "NISARGA HASSAN SREEDHAR",
            "entities" : [
                "attribute1" : {
                    "Atribname": "NAME",
                    "textDetected": "NISARGA HASSAN SREEDHAR",
                    "sChar": 0,
                    "eChar": 23
                }
            ]
        ],
        "sentence2": [
            "text": "San Jose, California",
            "entities" : [
                "attribute1" : {
                    "Atribname": "LOCATION",
                    "textDetected": "San Jose, California",
                    "sChar": 0,
                    "eChar": 18
                }
            ]
        ],
        "sentence3": [
            "text": "Programming: Python, Java",
            "entities" : [
                "attribute1" : {
                    "Atribname": "Programming Language",
                    "textDetected": "Python",
                    "sChar": 13,
                    "eChar": 18
                },
                "attribute2" : {
                    "Atribname": "Programming Language",
                    "textDetected": "Java",
                    "sChar": 20,
                    "eChar": 24
                }
            ]
        ],
        "sentence4": [
            "text": "Aug 2019 - Dec 2019",
            "entities" : [
                "attribute1" : {
                    "Atribname": "DATE",
                    "textDetected": "Aug 2019",
                    "sChar": 0,
                    "eChar": 12
                },
                "attribute2" : {
                    "Atribname": "DATE",
                    "textDetected": "Dec 2019",
                    "sChar": 16,
                    "eChar": 20
                }
            ]
        ]
    ]
}
"""

# %% [markdown]
# # Test Creating Loop for creating Sentences

# %%
wordCount = 0
elementList = []
for i in listofWords:
    elementGoing = ""
    print(str(wordCount) +  "   " +  i)
    elementContain = input("Does this contain a element")
    while elementContain == "" or not (elementContain == "n" or elementContain == "y") :
        elementContain = input("Does this contain a element")
    if elementContain == "Y" or elementContain == "y":
        elementGoing += i
        continueaddElement = input("Add more to this element?")
        while continueaddElement == "":
            continueaddElement = input("Add more to this element?")
        while continueaddElement == "Y" or continueaddElement == "y":
            print(listofWords[wordCount+1])
            countineElement2  = input("Add more to this element?")
            while countineElement2 == "":
                countineElement2 = input("Add more to this element?")
            while countineElement2 == "Y" or countineElement2 == "y":
                print(listofWords[wordCount+2])
                countineElement2 =  input("Add more to this element?")
        if continueaddElement == "x":
            break
    if elementContain == "x":
        break
    wordCount+=1
# Out:
# 0   NISARGA
# Does this contain a elementy
# Add more to this element?y
# HASSAN
# Add more to this element?y
# SREEDHAR
# San
# Add more to this element?n
# HASSAN
# Add more to this element?n
# HASSAN
# Add more to this element?n
# HASSAN
# Add more to this element?q
# HASSAN
# Add more to this element?x
# HASSAN
# Add more to this element?x
# HASSAN
# Add more to this element?x
# HASSAN

# %% [markdown]
# # Write a program that goes through the text file and extracts each entity and its starting position and ending position and its name

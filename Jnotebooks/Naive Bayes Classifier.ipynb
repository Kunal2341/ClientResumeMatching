# %%
from IPython.display import Image

# %% [markdown]
# # Naive Bayes Classifier
# By Kunal Aneja

# %% [markdown]
# ### What is it
# **A theorem that uses probability to calculate a specific probability**
#
# - P(A|B) --> conditional probability of A with respect to B

# %%
Image(filename="/Users/kunal/Desktop/img2.png")

# %%
Image(filename="/Users/kunal/Desktop/img.png")

# %% [markdown]
# ### Example: Emails

# %%
Image(filename="/Users/kunal/Desktop/img3.png")

# %% [markdown]
# - predict whether or not it’s spam
# - new case: **JOB**
# - is it spam or not?
# - compute some basic probabilities

# %%
Image(filename="/Users/kunal/Desktop/img4.png")

# %% [markdown]
# - Basic multiplication

# %%
Image(filename="/Users/kunal/Desktop/img5.png")

# %% [markdown]
# **Summary**
# - Probability for email being spam with the word JOB is 33%
# - Single vector/variable calculation

# %% [markdown]
# ## Different types of Naïve Bayes classifiers

# %%
In Gaussian Naive Bayes we assume that continuous value associated with each feature follow Gaussian distribution(Also known as normal distribution).

# %% [markdown]
# ###  Gaussian Naive Bayes

# %% [markdown]
# - Everything follows a normal distribution
# - Uses log probability --> to deal with edge lower probailites
# - only the **mean** and **standard deviation** of the data needs to be estimated.

# %%
Image(filename="/Users/kunal/Desktop/img6.gif")

# %% [markdown]
# ### Bernoulli

# %% [markdown]
# - Classify between **True** and **False**
# - Very simple code
# - Single Vector
# - Used in email example

# %% [markdown]
# ### Multinomial

# %% [markdown]
# - Used in Natrual Language Processing (NLP)
# - The term Multinomial Naive Bayes simply lets us know that each p(fi|c) is a multinomial distribution, rather than some other distribution. This works well for data which can easily be turned into counts, such as word counts in text.
# - Use multiple vectors/tokens (words) to calculate total sentence
# - Works with extract meaning of multiline words using a spider connection between each

# %%
Image(filename="/Users/kunal/Desktop/img7.png")

# %% [markdown]
# ## How I am going to be using it

# %% [markdown]
# - Extracting info from a resume
# - Unstructed data
# - Extract names
# - Understand what document means
# - Multiple **Different** types of resumes

# %%
#Example

# %%
def extract_email_addresses(string):
    r = re.compile(r'[\w\.-]+@[\w\.-]+')
    return r.findall(string)
